# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Juan Graciano
# - **Email:** juangraciano2349@gmail.com
# - **ID Dicoding:** juan_graciano_nyEN

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apa penyebab banyaknya peminjam sepeda?
# - Dari tahun 2011 hingga 2012, bagaimana perkembangan rental sepeda?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
#Untuk membaca data day.csv
day_df = pd.read_csv("./data/day.csv", delimiter=",")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
#Untuk membaca data hour.csv
hour_df = pd.read_csv("./data/hour.csv", delimiter=",")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [raw]
# **Insight:**
# - Dataset ini dibagi 2 yaitu day.csv yang berisi data peminjaman sepeda per hari dan hour.csv yang berisi data peminjaman sepeda per jam
# - Terdapat 15 kolom untuk day.csv dan 16 kolom untuk hour.csv
# - Dataset ini berisi beberapa kolom tentang waktu (tanggal, musim, tahun, jam, holiday, weekday, workingday) , cuaca, temperatur, dan jumlah peminjam sepeda
# - Beberapa kolom memiliki value dalam bentuk kode/token yang mewakilkan value tertentu
# - Kolom instant hanya berisi penomoran baris

# %% [markdown]
# ### Assessing Data

# %%
#Memeriksa detail data-type pada kedua tabel
day_df.info()
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
#Menilai tabel day
day_df.isna().sum()
print("Jumlah duplikasi: ", day_df.duplicated().sum())
day_df.describe()
# Out:
# Jumlah duplikasi:  0
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
#Menilai tabel hour
hour_df.isna().sum()
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
hour_df.describe()
# Out:
# Jumlah duplikasi:  0
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# **Insight:**
# - Berdasarkan penilaian, data yang digunakan bebas dari duplikasi dan data kosong.
# - Pada kedua tabel, sebagian besar tipe datanya adalah numerik (float dan integer).
# - Kolom dteday seharusnya bertipe date, bukan objek.
# - Pada kolom season, mnth, holiday, weekday, workingday dan weathersit seharusnya bertipe kategori
# - Kolom instant boleh dihapus karena hanya berisi penomoran baris

# %% [markdown]
# ### Cleaning Data

# %%
#Mengubah data type
columns = ['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit']
for column in columns:
    hour_df[column] = hour_df[column].astype("category")
    day_df[column] =  day_df[column].astype("category")
hour_df['hr'] = hour_df['hr'].astype("category")


#day
day_df['dteday'] = pd.to_datetime(day_df['dteday'])

#hour
hour_df['dteday'] = pd.to_datetime(day_df['dteday'])

# %%
#Drop kolom instant
hour_df.drop(['instant'], axis = 1, inplace= True)
day_df.drop(['instant'], axis = 1, inplace= True)

# %%
#Rename nama kolom
day_df.rename(columns=
              {'dteday':'dateday',
               'yr':'year',
               'mnth':'month', 
               'weathersit':'weather_situation', 
               'cnt':'count_total',
               'hum':'humidity'},inplace=True)

hour_df.rename(columns=
              {'dteday':'dateday',
               'yr':'year',
               'mnth':'month', 
               'hr' : 'hour',
               'weathersit':'weather_situation', 
               'cnt':'count_total',
               'hum':'humidity'},inplace=True)

# %%
#Replace angka menjadi keterangan
day_df['month'] = day_df['month'].map({
    1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'
})
day_df['season'] = day_df['season'].map({
    1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'
})
day_df['weekday'] = day_df['weekday'].map({
    0: 'Sun', 1: 'Mon', 2: 'Tue', 3: 'Wed', 4: 'Thu', 5: 'Fri', 6: 'Sat'
})
day_df['weather_situation'] = day_df['weather_situation'].map({
    1: 'Clear/Partly Cloudy', 2: 'Misty/Cloudy', 3: 'Light Snow/Rain', 4: 'Extreme Weather'
})

hour_df['month'] = hour_df['month'].map({
    1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'
})
hour_df['season'] = hour_df['season'].map({
    1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'
})
hour_df['weekday'] = hour_df['weekday'].map({
    0: 'Sun', 1: 'Mon', 2: 'Tue', 3: 'Wed', 4: 'Thu', 5: 'Fri', 6: 'Sat'
})
hour_df['weather_situation'] = hour_df['weather_situation'].map({
    1: 'Clear/Partly Cloudy', 2: 'Misty/Cloudy', 3: 'Light Snow/Rain', 4: 'Extreme Weather'
})

# %%
#Display data info
day_df.info()
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dateday            731 non-null    datetime64[ns]
#  1   season             731 non-null    category
#  2   year               731 non-null    category
#  3   month              731 non-null    category
#  4   holiday            731 non-null    category
#  5   weekday            731 non-null    category
#  6   workingday         731 non-null    category
#  7   weather_situation  731 non-null    category
#  8   temp               731 non-null    float64
#  9   atemp              731 non-null    float64
#  10  humidity           731 non-null    float64
#  11  windspeed          731 non-null    float64
#  12  casual             731 non-null    int64
#  13  registered         731 non-null    int64
#  14  count_total        731 non-null    int64
# ...

# %% [markdown]
# **Insight:**
# - Nama kolom harus diganti untuk memudahkan saat menganalisis
# - Tipe data yang tidak sesuai diganti
# - Value yang berbentuk kode/token angka diubah menjadi value sebenarnya

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Data Peminjam Sepeda Berdasarkan year, holiday, season, dan weather_situation

# %%
#Describe data
day_df.describe()
hour_df.describe()
# Out:
#                    dateday          temp         atemp      humidity  \
# count                  731  17379.000000  17379.000000  17379.000000
# mean   2012-01-01 00:00:00      0.496987      0.475775      0.627229
# min    2011-01-01 00:00:00      0.020000      0.000000      0.000000
# 25%    2011-07-02 12:00:00      0.340000      0.333300      0.480000
# 50%    2012-01-01 00:00:00      0.500000      0.484800      0.630000
# 75%    2012-07-01 12:00:00      0.660000      0.621200      0.780000
# max    2012-12-31 00:00:00      1.000000      1.000000      1.000000
# std                    NaN      0.192556      0.171850      0.192930
#
#           windspeed        casual    registered   count_total
# count  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.190098     35.676218    153.786869    189.463088
# min        0.000000      0.000000      0.000000      1.000000
# 25%        0.104500      4.000000     34.000000     40.000000
# ...

# %% [markdown]
# Berdasarkan hasil tersebut, keduanya memiliki total data yang sama (data hpada hour_df adalah data day_df yang dibuat per jam) sehingga saya hanya akan menggunakan day_df.

# %%
#Berdasarkan tahun
day_df.groupby(by='year').agg({
    'count_total': ['max', 'min', 'mean', 'sum']
})
# Out:
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\588226990.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_df.groupby(by='year').agg({
#      count_total
#              max  min         mean      sum
# year
# 0           6043  431  3405.761644  1243103
# 1           8714   22  5599.934426  2049576

# %% [markdown]
# Pengelompokkan data berdasarkan tahun dengan keterangan 0 adalah tahun 2011 dan 1 adalah tahun 2012. Jumlah data count_total pada tahun 2012 lebih banyak daripada tahun 2011

# %%
#Berdasarkan bulan
day_df.groupby(by=['year','month']).agg({
    'count_total': ['max', 'min', 'mean', 'sum']
})
# Out:
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\2294419148.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_df.groupby(by=['year','month']).agg({
#            count_total
#                    max   min         mean     sum
# year month
# 0    Jan          1985   431  1231.903226   38189
#      Feb          2927  1005  1721.964286   48215
#      Mar          3239   605  2065.967742   64045
#      Apr          5312   795  3162.333333   94870
#      May          5805  2633  4381.322581  135821
#      Jun          5515  3767  4783.733333  143512
#      Jul          6043  3285  4559.387097  141341
#      Aug          5895  1115  4409.387097  136691
#      Sep          5423  1842  4247.266667  127418
#      Oct          5511   627  3984.225806  123511
# ...

# %% [markdown]
# Data di atas adalah data count_total setiap bulan selama 2*12 bulan. Pada bulan yang sama dan tahun yang berbeda, data count_total lebih tinggi di tahun 2012

# %%
#Berdasarkan hari libur
day_df.groupby(by='holiday').agg({
    'count_total': ['max', 'min', 'mean', 'sum']
})
# Out:
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\1287844268.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_df.groupby(by='holiday').agg({
#         count_total
#                 max   min         mean      sum
# holiday
# 0              8714    22  4527.104225  3214244
# 1              7403  1000  3735.000000    78435

# %% [markdown]
# Pengelompokkan data berdasarkan tahun dengan keterangan 0 adalah hari tidak libur (non-holiday) dan 1 adalah tahun hari libur (holiday). Data count_total pada hari tidak libur lebih banyak daripada hari libur

# %%
#Berdasarkan musim
day_df.groupby(by='season').agg({
    'count_total': ['max', 'min', 'mean', 'sum']
})
# Out:
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\1334360778.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_df.groupby(by='season').agg({
#        count_total
#                max   min         mean      sum
# season
# Spring        7836   431  2604.132597   471348
# Summer        8362   795  4992.331522   918589
# Fall          8714  1115  5644.303191  1061129
# Winter        8555    22  4728.162921   841613

# %% [markdown]
# Pengelompokkan berdasarkan musim tidak memberikan hasil yang jelas karena kecuali saat musim semi (spring), penyebaran data count_total cukup merata. Saya akan coba analisis apakah ada pengaruh musim ke temperatur dan humidity.

# %%
#Temperatur dan humidity berdasarkan musim
day_df.groupby(by='season').agg({
    'temp': ['max', 'min', 'mean'],
    'atemp': ['max', 'min', 'mean'],
    'humidity': ['max', 'min', 'mean']
})
# Out:
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\1720028642.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_df.groupby(by='season').agg({
#             temp                         atemp                      humidity  \
#              max       min      mean       max       min      mean       max
# season
# Spring  0.572500  0.059130  0.297748  0.548617  0.079070  0.296914  0.948261
# Summer  0.808333  0.253043  0.544405  0.757579  0.250339  0.520307  0.922500
# Fall    0.861667  0.469167  0.706309  0.840896  0.242400  0.655898  0.939565
# Winter  0.657500  0.220833  0.422906  0.607975  0.227913  0.415539  0.972500
#
#
#              min      mean
# season
# Spring  0.000000  0.582903
# Summer  0.254167  0.626948
# Fall    0.360000  0.633482
# Winter  0.333478  0.668719

# %% [markdown]
# Dari data ini, tidak ada perbedaan yang jelas yang menyebabkan data count_total lebih tinggi saat musim gugur dan rendahnya data count_total pada musim semi. Saya akan coba analisis dari kondisi cuaca

# %%
day_df.groupby(by='weather_situation').agg({
    'count_total': ['max', 'min', 'mean', 'sum']
})
# Out:
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\1821316351.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_df.groupby(by='weather_situation').agg({
#                     count_total
#                             max  min         mean      sum
# weather_situation
# Clear/Partly Cloudy        8714  431  4876.786177  2257952
# Misty/Cloudy               8362  605  4035.862348   996858
# Light Snow/Rain            4639   22  1803.285714    37869

# %% [markdown]
# Pengelompokkan berdasarkan cuaca menghasilkan perbedaan data yang jelas. Cuaca cerah memiliki data count_total paling tinggi. Apakah perbedaan temperatur pada cuaca tertentu berpengaruh?

# %%
day_df.groupby(by='weather_situation').agg({
    'temp': ['max', 'min', 'mean'],
    'atemp': ['max', 'min', 'mean'],
    'humidity': ['max', 'min', 'mean']
})
# Out:
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\3160158305.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_df.groupby(by='weather_situation').agg({
#                          temp                        atemp            \
#                           max      min      mean       max       min
# weather_situation
# Clear/Partly Cloudy  0.861667  0.05913  0.511541  0.840896  0.079070
# Misty/Cloudy         0.815000  0.10750  0.470366  0.826371  0.119337
# Light Snow/Rain      0.633913  0.21750  0.433440  0.555361  0.203600
#
#                                humidity
#                          mean       max       min      mean
# weather_situation
# Clear/Partly Cloudy  0.488596  0.835833  0.187917  0.565594
# Misty/Cloudy         0.452868  0.972500  0.407083  0.725887
# ...

# %% [markdown]
# Dari data di atas, dapat disimpulkan bahwa peminjam sepeda akan memilih saat temperatur lebih tinggi dan humidity lebih rendah.

# %% [markdown]
# **Insight:**
# - Data dikelompokkan menjadi beberapa kelompok berdasarkan kebutuhan untuk menjawab pertanyaan yang sudah dibuat
# - Beberapa kelompok memiliki perbedaan jumlah peminjam yang signifikan.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Apa penyebab banyaknya peminjam sepeda?

# %%
#Faktor cuaca
colors = ["#0561f5", "#D3D3D3", "#D3D3D3"]
weather_df= day_df.groupby(by="weather_situation")['count_total'].sum().reset_index()
sns.barplot(x="weather_situation", y="count_total", data=weather_df.sort_values(by='count_total', ascending=False),ci=None, palette=colors)

plt.title("Total Rental Bikes in Various Weather")
plt.xlabel("Weather Condition")
plt.ylabel("Total Rental Bikes")
for i, value in enumerate(weather_df.sort_values(by='count_total', ascending=False)['count_total']):
    plt.text(i, value + 10, f'{value}', ha='center', va='bottom')
plt.show()
# Out:
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\4162567501.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weather_df= day_df.groupby(by="weather_situation")['count_total'].sum().reset_index()
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\4162567501.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="weather_situation", y="count_total", data=weather_df.sort_values(by='count_total', ascending=False),ci=None, palette=colors)
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\4162567501.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# Rental sepeda lebih banyak saat cuaca lebih mendukung (cerah dan berawan)

# %%
#Faktor holiday
colors = ["#0561f5", "#D3D3D3"]
holiday_df= day_df.groupby(by="holiday")['count_total'].mean().reset_index()
sns.barplot(x="holiday", y="count_total", data=holiday_df.sort_values(by='holiday', ascending=False),ci=None, palette=colors)
plt.title("Average Rental Bikes in Holiday")
plt.xlabel("Holiday (0=non-Holiday, 1=Holiday)")
plt.ylabel("Average Rental Bikes")
for i, value in enumerate(holiday_df.sort_values(by='count_total', ascending=False)['count_total']):
    plt.text(i, value + 10, f'{value}', ha='center', va='bottom')
plt.show()
# Out:
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\765448160.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   holiday_df= day_df.groupby(by="holiday")['count_total'].mean().reset_index()
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\765448160.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="holiday", y="count_total", data=holiday_df.sort_values(by='holiday', ascending=False),ci=None, palette=colors)
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\765448160.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# Karena hari libur lebih sedikit daripada hari tidak lobur, maka saya menggunakan mean dan hasilnya rental sepeda lebih banyak saat hari tidak libur.

# %% [markdown]
# ### Pertanyaan 2: Dari tahun 2011 hingga 2012, bagaimana perkembangan rental sepeda?

# %%
#Perbandingan per bulan
day_df['month'] = day_df['dateday'].dt.to_period('M')
monthly_data = day_df.groupby('month')['count_total'].sum()
plt.plot(monthly_data.index.astype(str), monthly_data.values, color='red', marker='o')
plt.xticks(rotation=60);
plt.xlabel("Year-Month")
plt.ylabel("Total Rental Bikes")
plt.title("Development of Rental Bikes")
plt.show()

# %% [markdown]
# Rental sepeda pada tahun 2012 meningkat dari tahun sebelumnya.

# %% [markdown]
# **Insight:**
# - Peminjam sepeda terbanyak ada saat cuaca cerah
# - Total peminjam sepeda pada tahun 2012 lebih banyak dari tahun sebelumnya

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# **Clustering**

# %%
def temp_group(temp):
    if temp<0.34:
        return "Low"
    elif 0.34<= temp <= 0.65:
        return "Medium"
    else:
        return "High"
day_df['temp_category'] = day_df['temp'].apply(temp_group)
colors = ["#0561f5", "#D3D3D3", "#D3D3D3"]
temp_df= day_df.groupby(by="temp_category")['count_total'].sum().reset_index()
sns.barplot(x="temp_category", y="count_total", data=temp_df.sort_values(by='temp_category', ascending=False),ci=None, palette=colors)
plt.title("Average Rental Bikes in Holiday")
plt.xlabel("Holiday (0=non-Holiday, 1=Holiday)")
plt.ylabel("Average Rental Bikes")
for i, value in enumerate(temp_df.sort_values(by='temp_category', ascending=False)['count_total']):
    plt.text(i, value + 10, f'{value}', ha='center', va='bottom')
plt.show()
# Out:
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\1070471519.py:11: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="temp_category", y="count_total", data=temp_df.sort_values(by='temp_category', ascending=False),ci=None, palette=colors)
# C:\Users\frand\AppData\Local\Temp\ipykernel_34356\1070471519.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="temp_category", y="count_total", data=temp_df.sort_values(by='temp_category', ascending=False),ci=None, palette=colors)

# %% [markdown]
# Berdasarkan data tersebut, temperatur juga berpengaruh pada jumlah rental sepeda. Pengelompokkan dibuat berdasarkan IQR temperatur

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Penyebab banyaknya peminjam sepeda adalah cuaca yang cenderung cerah (menyebabkan temperatur lebih tinggi) dan hari tidak libur
# - Peminjam sepeda lebih banyak saat temperatur sedang hingga tinggi.
# - Jumlah peminjam per bulan pada 2012 lebih tinggi dari 2011 yang artinya total rental sepeda meningkat tiap tahunnya

# %% [markdown]
# # i
